# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 590

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=87907aa6da69bd7f8bf358aa1b4d4c38

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    # Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kavaratti
# Processing Record 2 of Set 1 | provideniya
# Processing Record 3 of Set 1 | baykit
# Processing Record 4 of Set 1 | jutai
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | leh
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 1 | tasiilaq
# Processing Record 10 of Set 1 | batagay
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | cidreira
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 1 | alta floresta
# Processing Record 17 of Set 1 | alofi
# Processing Record 18 of Set 1 | kaitangata
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | baker city
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | isla vista
# Processing Record 24 of Set 1 | bengkulu
# Processing Record 25 of Set 1 | matay
# Processing Record 26 of Set 1 | victoria
# Processing Record 27 of Set 1 | baiyin
# Processing Record 28 of Set 1 | butaritari
# Processing Record 29 of Set 1 | pacific grove
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | vila velha
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | kruisfontein
# Processing Record 37 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | masallatah
# Processing Record 40 of Set 1 | biloela
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | katsuura
# Processing Record 43 of Set 1 | san policarpo
# Processing Record 44 of Set 1 | mahebourg
# Processing Record 45 of Set 1 | starozhilovo
# Processing Record 46 of Set 1 | geraldton
# Processing Record 47 of Set 1 | rikitea
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 1 | gondanglegi
# Processing Record 1 of Set 2 | taoudenni
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | salym
# Processing Record 4 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 2 | cap malheureux
# Processing Record 6 of Set 2 | mathbaria
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | wahran
# City not found. Skipping...
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | saint anthony
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | tanabi
# Processing Record 16 of Set 2 | laguna
# Processing Record 17 of Set 2 | bahile
# Processing Record 18 of Set 2 | caravelas
# Processing Record 19 of Set 2 | labuhan
# Processing Record 20 of Set 2 | gorom-gorom
# Processing Record 21 of Set 2 | san ramon
# Processing Record 22 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 2 | barrow
# Processing Record 24 of Set 2 | thompson
# Processing Record 25 of Set 2 | porto novo
# Processing Record 26 of Set 2 | melilla
# Processing Record 27 of Set 2 | fortuna
# Processing Record 28 of Set 2 | valle hermoso
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | mazamari
# Processing Record 32 of Set 2 | ancud
# Processing Record 33 of Set 2 | wanning
# Processing Record 34 of Set 2 | longyearbyen
# Processing Record 35 of Set 2 | faanui
# Processing Record 36 of Set 2 | port lincoln
# Processing Record 37 of Set 2 | punta arenas
# Processing Record 38 of Set 2 | christchurch
# Processing Record 39 of Set 2 | wanganui
# Processing Record 40 of Set 2 | tuktoyaktuk
# Processing Record 41 of Set 2 | hilo
# Processing Record 42 of Set 2 | saskylakh
# Processing Record 43 of Set 2 | ozinki
# Processing Record 44 of Set 2 | beringovskiy
# Processing Record 45 of Set 2 | dingle
# Processing Record 46 of Set 2 | samarai
# Processing Record 47 of Set 2 | lebu
# Processing Record 48 of Set 2 | touros
# Processing Record 49 of Set 2 | karasburg
# Processing Record 50 of Set 2 | balkanabat
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | shubarkuduk
# Processing Record 3 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 3 | ostrovnoy
# Processing Record 5 of Set 3 | vysokogornyy
# Processing Record 6 of Set 3 | kodiak
# Processing Record 7 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 3 | grand-lahou
# Processing Record 9 of Set 3 | chernyshkovskiy
# Processing Record 10 of Set 3 | shimoda
# Processing Record 11 of Set 3 | guarumal
# Processing Record 12 of Set 3 | punakha
# Processing Record 13 of Set 3 | norman wells
# Processing Record 14 of Set 3 | acarau
# Processing Record 15 of Set 3 | arlit
# Processing Record 16 of Set 3 | garden city
# Processing Record 17 of Set 3 | khatanga
# Processing Record 18 of Set 3 | castro
# Processing Record 19 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 3 | eirunepe
# Processing Record 21 of Set 3 | severo-kurilsk
# Processing Record 22 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 3 | los llanos de aridane
# Processing Record 24 of Set 3 | hasaki
# Processing Record 25 of Set 3 | marrakesh
# Processing Record 26 of Set 3 | portland
# Processing Record 27 of Set 3 | kalmunai
# Processing Record 28 of Set 3 | bara
# Processing Record 29 of Set 3 | tiksi
# Processing Record 30 of Set 3 | maun
# Processing Record 31 of Set 3 | kloulklubed
# Processing Record 32 of Set 3 | hovd
# Processing Record 33 of Set 3 | kidal
# Processing Record 34 of Set 3 | yumen
# Processing Record 35 of Set 3 | araouane
# Processing Record 36 of Set 3 | jamestown
# Processing Record 37 of Set 3 | henties bay
# Processing Record 38 of Set 3 | bozoum
# Processing Record 39 of Set 3 | manado
# Processing Record 40 of Set 3 | ulaanbaatar
# Processing Record 41 of Set 3 | bambanglipuro
# Processing Record 42 of Set 3 | marktredwitz
# Processing Record 43 of Set 3 | chuy
# Processing Record 44 of Set 3 | san quintin
# Processing Record 45 of Set 3 | sao tome
# Processing Record 46 of Set 3 | quatre cocos
# Processing Record 47 of Set 3 | new norfolk
# Processing Record 48 of Set 3 | toulepleu
# City not found. Skipping...
# Processing Record 49 of Set 3 | pangnirtung
# Processing Record 50 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 4 | changji
# Processing Record 2 of Set 4 | bradford
# Processing Record 3 of Set 4 | san cristobal
# Processing Record 4 of Set 4 | leningradskiy
# Processing Record 5 of Set 4 | morondava
# Processing Record 6 of Set 4 | kavieng
# Processing Record 7 of Set 4 | hithadhoo
# Processing Record 8 of Set 4 | tinaquillo
# Processing Record 9 of Set 4 | kumba
# Processing Record 10 of Set 4 | tual
# Processing Record 11 of Set 4 | semenivka
# Processing Record 12 of Set 4 | narsaq
# Processing Record 13 of Set 4 | coos bay
# Processing Record 14 of Set 4 | seoul
# Processing Record 15 of Set 4 | kontagora
# Processing Record 16 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 4 | bilibino
# Processing Record 18 of Set 4 | cabo san lucas
# Processing Record 19 of Set 4 | maymyo
# Processing Record 20 of Set 4 | delmas
# Processing Record 21 of Set 4 | mitsamiouli
# Processing Record 22 of Set 4 | bambous virieux
# Processing Record 23 of Set 4 | ankazoabo
# Processing Record 24 of Set 4 | elk city
# Processing Record 25 of Set 4 | saint george
# Processing Record 26 of Set 4 | lianran
# Processing Record 27 of Set 4 | yerofey pavlovich
# Processing Record 28 of Set 4 | jever
# Processing Record 29 of Set 4 | hermanus
# Processing Record 30 of Set 4 | saint-philippe
# Processing Record 31 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 4 | jiuquan
# Processing Record 33 of Set 4 | grande prairie
# Processing Record 34 of Set 4 | tecolutla
# Processing Record 35 of Set 4 | kasane
# Processing Record 36 of Set 4 | brae
# Processing Record 37 of Set 4 | beyneu
# Processing Record 38 of Set 4 | tampakan
# Processing Record 39 of Set 4 | konstantinovka
# Processing Record 40 of Set 4 | nuuk
# Processing Record 41 of Set 4 | bathsheba
# Processing Record 42 of Set 4 | luang prabang
# Processing Record 43 of Set 4 | pitimbu
# Processing Record 44 of Set 4 | lagoa
# Processing Record 45 of Set 4 | natal
# Processing Record 46 of Set 4 | inhambane
# Processing Record 47 of Set 4 | qaanaaq
# Processing Record 48 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 49 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 50 of Set 4 | okha
# Processing Record 1 of Set 5 | tiznit
# Processing Record 2 of Set 5 | san patricio
# Processing Record 3 of Set 5 | goya
# Processing Record 4 of Set 5 | porto empedocle
# Processing Record 5 of Set 5 | chimore
# Processing Record 6 of Set 5 | dunedin
# Processing Record 7 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 5 | makasar
# Processing Record 9 of Set 5 | saldanha
# Processing Record 10 of Set 5 | tynda
# Processing Record 11 of Set 5 | kendari
# Processing Record 12 of Set 5 | chunoyar
# Processing Record 13 of Set 5 | cherskiy
# Processing Record 14 of Set 5 | hami
# Processing Record 15 of Set 5 | husavik
# Processing Record 16 of Set 5 | atasu
# Processing Record 17 of Set 5 | medvezhyegorsk
# Processing Record 18 of Set 5 | olga
# Processing Record 19 of Set 5 | westport
# Processing Record 20 of Set 5 | tilichiki
# Processing Record 21 of Set 5 | oistins
# Processing Record 22 of Set 5 | pimentel
# Processing Record 23 of Set 5 | shenjiamen
# Processing Record 24 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 5 | yulara
# Processing Record 26 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 28 of Set 5 | adrar
# Processing Record 29 of Set 5 | tura
# Processing Record 30 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 5 | harlingen
# Processing Record 32 of Set 5 | ponta do sol
# Processing Record 33 of Set 5 | pevek
# Processing Record 34 of Set 5 | pisco
# Processing Record 35 of Set 5 | mangrol
# Processing Record 36 of Set 5 | garoua boulai
# Processing Record 37 of Set 5 | richards bay
# Processing Record 38 of Set 5 | kadoma
# Processing Record 39 of Set 5 | nanakuli
# Processing Record 40 of Set 5 | chadiza
# Processing Record 41 of Set 5 | constitucion
# Processing Record 42 of Set 5 | staryy krym
# Processing Record 43 of Set 5 | sayyan
# Processing Record 44 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 5 | nikolskoye
# Processing Record 46 of Set 5 | bababe
# City not found. Skipping...
# Processing Record 47 of Set 5 | ribeira grande
# Processing Record 48 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 5 | iskitim
# Processing Record 50 of Set 5 | joshimath
# Processing Record 1 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 6 | lumberton
# Processing Record 3 of Set 6 | halifax
# Processing Record 4 of Set 6 | senneterre
# Processing Record 5 of Set 6 | ganzhou
# Processing Record 6 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 7 of Set 6 | mackay
# Processing Record 8 of Set 6 | dikson
# Processing Record 9 of Set 6 | searcy
# Processing Record 10 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 6 | nishihara
# Processing Record 12 of Set 6 | mount gambier
# Processing Record 13 of Set 6 | masumbwe
# Processing Record 14 of Set 6 | port hardy
# Processing Record 15 of Set 6 | bonthe
# Processing Record 16 of Set 6 | caarapo
# Processing Record 17 of Set 6 | viedma
# Processing Record 18 of Set 6 | swan river
# Processing Record 19 of Set 6 | kohlu
# Processing Record 20 of Set 6 | chum phae
# Processing Record 21 of Set 6 | puerto cabezas
# Processing Record 22 of Set 6 | teahupoo
# Processing Record 23 of Set 6 | jieshi
# Processing Record 24 of Set 6 | vung tau
# Processing Record 25 of Set 6 | margate
# Processing Record 26 of Set 6 | atar
# Processing Record 27 of Set 6 | acapulco
# Processing Record 28 of Set 6 | plattsburgh
# Processing Record 29 of Set 6 | klaksvik
# Processing Record 30 of Set 6 | dali
# Processing Record 31 of Set 6 | souillac
# Processing Record 32 of Set 6 | high level
# Processing Record 33 of Set 6 | cayenne
# Processing Record 34 of Set 6 | novomykolayivka
# Processing Record 35 of Set 6 | phumi samraong
# City not found. Skipping...
# Processing Record 36 of Set 6 | grojec
# Processing Record 37 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 38 of Set 6 | plonsk
# Processing Record 39 of Set 6 | gat
# Processing Record 40 of Set 6 | birao
# Processing Record 41 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 42 of Set 6 | ramsar
# Processing Record 43 of Set 6 | shestakovo
# Processing Record 44 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 6 | meulaboh
# Processing Record 46 of Set 6 | robore
# Processing Record 47 of Set 6 | pochutla
# Processing Record 48 of Set 6 | antalaha
# Processing Record 49 of Set 6 | hisai
# Processing Record 50 of Set 6 | esmeraldas
# Processing Record 1 of Set 7 | esperance
# Processing Record 2 of Set 7 | college
# Processing Record 3 of Set 7 | gamba
# Processing Record 4 of Set 7 | guacimo
# Processing Record 5 of Set 7 | ambilobe
# Processing Record 6 of Set 7 | aklavik
# Processing Record 7 of Set 7 | sao filipe
# Processing Record 8 of Set 7 | eureka
# Processing Record 9 of Set 7 | hualmay
# Processing Record 10 of Set 7 | awjilah
# Processing Record 11 of Set 7 | mutare
# Processing Record 12 of Set 7 | tabou
# Processing Record 13 of Set 7 | daru
# Processing Record 14 of Set 7 | poum
# Processing Record 15 of Set 7 | puksoozero
# Processing Record 16 of Set 7 | roxana
# Processing Record 17 of Set 7 | san jose
# Processing Record 18 of Set 7 | belmonte
# Processing Record 19 of Set 7 | port hedland
# Processing Record 20 of Set 7 | sechura
# Processing Record 21 of Set 7 | iralaya
# Processing Record 22 of Set 7 | shelburne
# Processing Record 23 of Set 7 | forbes
# Processing Record 24 of Set 7 | nabire
# Processing Record 25 of Set 7 | barranca
# Processing Record 26 of Set 7 | angoram
# Processing Record 27 of Set 7 | lompoc
# Processing Record 28 of Set 7 | la rioja
# Processing Record 29 of Set 7 | santa vitoria do palmar
# Processing Record 30 of Set 7 | piacabucu
# Processing Record 31 of Set 7 | asau
# Processing Record 32 of Set 7 | hamilton
# Processing Record 33 of Set 7 | torbay
# Processing Record 34 of Set 7 | fort oglethorpe
# Processing Record 35 of Set 7 | lazaro cardenas
# Processing Record 36 of Set 7 | sinnamary
# Processing Record 37 of Set 7 | aljezur
# Processing Record 38 of Set 7 | stornoway
# Processing Record 39 of Set 7 | sisimiut
# Processing Record 40 of Set 7 | gryfice
# Processing Record 41 of Set 7 | udalguri
# Processing Record 42 of Set 7 | vila praia de ancora
# Processing Record 43 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 44 of Set 7 | guerrero negro
# Processing Record 45 of Set 7 | la palma
# Processing Record 46 of Set 7 | mount isa
# Processing Record 47 of Set 7 | kasongo
# Processing Record 48 of Set 7 | kanniyakumari
# Processing Record 49 of Set 7 | sabha
# Processing Record 50 of Set 7 | beni
# Processing Record 1 of Set 8 | sioux lookout
# Processing Record 2 of Set 8 | taltal
# Processing Record 3 of Set 8 | cockburn town
# Processing Record 4 of Set 8 | auki
# Processing Record 5 of Set 8 | sandwick
# Processing Record 6 of Set 8 | belyy yar
# Processing Record 7 of Set 8 | buritis
# Processing Record 8 of Set 8 | springbok
# Processing Record 9 of Set 8 | candawaga
# City not found. Skipping...
# Processing Record 10 of Set 8 | omboue
# Processing Record 11 of Set 8 | naze
# Processing Record 12 of Set 8 | otane
# Processing Record 13 of Set 8 | clyde river
# Processing Record 14 of Set 8 | komsomolskiy
# Processing Record 15 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 16 of Set 8 | garowe
# Processing Record 17 of Set 8 | ucluelet
# Processing Record 18 of Set 8 | tongliao
# Processing Record 19 of Set 8 | sungairaya
# Processing Record 20 of Set 8 | lata
# Processing Record 21 of Set 8 | sanmenxia
# Processing Record 22 of Set 8 | magaria
# Processing Record 23 of Set 8 | khed brahma
# Processing Record 24 of Set 8 | ishigaki
# Processing Record 25 of Set 8 | talawdi
# City not found. Skipping...
# Processing Record 26 of Set 8 | ciudad bolivar
# Processing Record 27 of Set 8 | ahipara
# Processing Record 28 of Set 8 | bilokurakyne
# Processing Record 29 of Set 8 | porto belo
# Processing Record 30 of Set 8 | kondinskoye
# Processing Record 31 of Set 8 | genhe
# Processing Record 32 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 8 | guilin
# Processing Record 34 of Set 8 | rawson
# Processing Record 35 of Set 8 | chenghai
# Processing Record 36 of Set 8 | wukari
# Processing Record 37 of Set 8 | chirongui
# Processing Record 38 of Set 8 | georgiyevka
# Processing Record 39 of Set 8 | labrea
# Processing Record 40 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 41 of Set 8 | sala
# Processing Record 42 of Set 8 | aguas formosas
# Processing Record 43 of Set 8 | pecos
# Processing Record 44 of Set 8 | anito
# Processing Record 45 of Set 8 | okhotsk
# Processing Record 46 of Set 8 | lima
# Processing Record 47 of Set 8 | rehoboth
# Processing Record 48 of Set 8 | santa cruz cabralia
# Processing Record 49 of Set 8 | channel-port aux basques
# Processing Record 50 of Set 8 | tomigusuku
# Processing Record 1 of Set 9 | broken hill
# Processing Record 2 of Set 9 | lixourion
# Processing Record 3 of Set 9 | luderitz
# Processing Record 4 of Set 9 | araguacu
# Processing Record 5 of Set 9 | codrington
# Processing Record 6 of Set 9 | jinchang
# Processing Record 7 of Set 9 | mwinilunga
# Processing Record 8 of Set 9 | kamenka
# Processing Record 9 of Set 9 | nelson bay
# Processing Record 10 of Set 9 | svetlogorsk
# Processing Record 11 of Set 9 | a
# City not found. Skipping...
# Processing Record 12 of Set 9 | mala
# Processing Record 13 of Set 9 | hvide sande
# Processing Record 14 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 15 of Set 9 | pemangkat
# Processing Record 16 of Set 9 | north branch
# Processing Record 17 of Set 9 | kangaatsiaq
# Processing Record 18 of Set 9 | itarema
# Processing Record 19 of Set 9 | bilma
# Processing Record 20 of Set 9 | narayanpet
# Processing Record 21 of Set 9 | luganville
# Processing Record 22 of Set 9 | jibuti
# Processing Record 23 of Set 9 | amposta
# Processing Record 24 of Set 9 | praia
# Processing Record 25 of Set 9 | indianola
# Processing Record 26 of Set 9 | bossembele
# City not found. Skipping...
# Processing Record 27 of Set 9 | adelaide
# Processing Record 28 of Set 9 | shache
# Processing Record 29 of Set 9 | grimari
# City not found. Skipping...
# Processing Record 30 of Set 9 | guanica
# Processing Record 31 of Set 9 | buon me thuot
# City not found. Skipping...
# Processing Record 32 of Set 9 | kattivakkam
# Processing Record 33 of Set 9 | preobrazheniye
# Processing Record 34 of Set 9 | concepcion
# Processing Record 35 of Set 9 | plouzane
# Processing Record 36 of Set 9 | correntina
# Processing Record 37 of Set 9 | flin flon
# Processing Record 38 of Set 9 | maxixe
# Processing Record 39 of Set 9 | danville
# Processing Record 40 of Set 9 | asosa
# Processing Record 41 of Set 9 | langarud
# Processing Record 42 of Set 9 | dubenskiy
# City not found. Skipping...
# Processing Record 43 of Set 9 | andenes
# Processing Record 44 of Set 9 | alice springs
# Processing Record 45 of Set 9 | kulhudhuffushi
# Processing Record 46 of Set 9 | kipushi
# Processing Record 47 of Set 9 | coihaique
# Processing Record 48 of Set 9 | hagavik
# Processing Record 49 of Set 9 | vestmannaeyjar
# Processing Record 50 of Set 9 | beloha
# Processing Record 1 of Set 10 | saint-augustin
# Processing Record 2 of Set 10 | chicama
# Processing Record 3 of Set 10 | kimberley
# Processing Record 4 of Set 10 | kudahuvadhoo
# Processing Record 5 of Set 10 | launceston
# Processing Record 6 of Set 10 | puqi
# Processing Record 7 of Set 10 | namibe
# Processing Record 8 of Set 10 | bonavista
# Processing Record 9 of Set 10 | oktyabrskiy
# Processing Record 10 of Set 10 | sao joao da barra
# Processing Record 11 of Set 10 | poya
# Processing Record 12 of Set 10 | yabelo
# Processing Record 13 of Set 10 | burns lake
# Processing Record 14 of Set 10 | tevaitoa
# Processing Record 15 of Set 10 | moron
# Processing Record 16 of Set 10 | rocha
# Processing Record 17 of Set 10 | general pico
# Processing Record 18 of Set 10 | canutama
# Processing Record 19 of Set 10 | san-pedro
# Processing Record 20 of Set 10 | tambura
# Processing Record 21 of Set 10 | tsiroanomandidy
# Processing Record 22 of Set 10 | churapcha
# Processing Record 23 of Set 10 | progreso
# Processing Record 24 of Set 10 | itoman
# Processing Record 25 of Set 10 | havelock
# Processing Record 26 of Set 10 | anchorage
# Processing Record 27 of Set 10 | banjar
# Processing Record 28 of Set 10 | cozumel
# Processing Record 29 of Set 10 | oktyabrskoye
# Processing Record 30 of Set 10 | talnakh
# Processing Record 31 of Set 10 | valparaiso
# Processing Record 32 of Set 10 | bundaberg
# Processing Record 33 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 34 of Set 10 | weyburn
# Processing Record 35 of Set 10 | salalah
# Processing Record 36 of Set 10 | kualakapuas
# Processing Record 37 of Set 10 | port hawkesbury
# Processing Record 38 of Set 10 | tautira
# Processing Record 39 of Set 10 | khandyga
# Processing Record 40 of Set 10 | hokitika
# Processing Record 41 of Set 10 | muisne
# Processing Record 42 of Set 10 | diego de almagro
# Processing Record 43 of Set 10 | abu kamal
# Processing Record 44 of Set 10 | huarmey
# Processing Record 45 of Set 10 | kampot
# Processing Record 46 of Set 10 | matara
# Processing Record 47 of Set 10 | malpe
# Processing Record 48 of Set 10 | loralai
# Processing Record 49 of Set 10 | kamaishi
# Processing Record 50 of Set 10 | sampit
# Processing Record 1 of Set 11 | micheweni
# Processing Record 2 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 11 | hobyo
# Processing Record 4 of Set 11 | lavrentiya
# Processing Record 5 of Set 11 | mayumba
# Processing Record 6 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 7 of Set 11 | santa isabel do rio negro
# Processing Record 8 of Set 11 | vaitape
# Processing Record 9 of Set 11 | fare
# Processing Record 10 of Set 11 | lorengau
# Processing Record 11 of Set 11 | luebo
# Processing Record 12 of Set 11 | general nakar
# Processing Record 13 of Set 11 | urcos
# Processing Record 14 of Set 11 | egvekinot
# Processing Record 15 of Set 11 | isangel
# Processing Record 16 of Set 11 | benghazi
# Processing Record 17 of Set 11 | aksarka
# Processing Record 18 of Set 11 | sakakah
# Processing Record 19 of Set 11 | ode
# Processing Record 20 of Set 11 | ilulissat
# Processing Record 21 of Set 11 | ouango
# Processing Record 22 of Set 11 | siva
# Processing Record 23 of Set 11 | obodivka
# Processing Record 24 of Set 11 | virginia beach
# Processing Record 25 of Set 11 | alugan
# Processing Record 26 of Set 11 | trincomalee
# Processing Record 27 of Set 11 | tendukheda
# Processing Record 28 of Set 11 | beira
# Processing Record 29 of Set 11 | batagay-alyta
# Processing Record 30 of Set 11 | goderich
# Processing Record 31 of Set 11 | kawambwa
# Processing Record 32 of Set 11 | boden
# Processing Record 33 of Set 11 | sungaipenuh
# Processing Record 34 of Set 11 | baft
# Processing Record 35 of Set 11 | port shepstone
# Processing Record 36 of Set 11 | noyabrsk
# Processing Record 37 of Set 11 | hofn
# Processing Record 38 of Set 11 | grand gaube
# Processing Record 39 of Set 11 | verkhnevilyuysk
# Processing Record 40 of Set 11 | bridgeton
# Processing Record 41 of Set 11 | zaoyang
# Processing Record 42 of Set 11 | rodino
# Processing Record 43 of Set 11 | grafton
# Processing Record 44 of Set 11 | panama city
# Processing Record 45 of Set 11 | herisau
# Processing Record 46 of Set 11 | umm kaddadah
# Processing Record 47 of Set 11 | fairbanks
# Processing Record 48 of Set 11 | sistranda
# Processing Record 49 of Set 11 | manzhouli
# Processing Record 50 of Set 11 | mkushi
# Processing Record 1 of Set 12 | saint-ambroise
# Processing Record 2 of Set 12 | igarka
# Processing Record 3 of Set 12 | morro bay
# Processing Record 4 of Set 12 | anori
# Processing Record 5 of Set 12 | palaikastron
# Processing Record 6 of Set 12 | necochea
# Processing Record 7 of Set 12 | coquimbo
# Processing Record 8 of Set 12 | sur
# Processing Record 9 of Set 12 | ondarroa
# Processing Record 10 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 11 of Set 12 | aksu
# Processing Record 12 of Set 12 | muros
# Processing Record 13 of Set 12 | guinabsan
# Processing Record 14 of Set 12 | olafsvik
# Processing Record 15 of Set 12 | bubaque
# Processing Record 16 of Set 12 | nacala
# Processing Record 17 of Set 12 | beysehir
# Processing Record 18 of Set 12 | tbilisskaya
# Processing Record 19 of Set 12 | whitianga
# Processing Record 20 of Set 12 | bogorodskoye
# Processing Record 21 of Set 12 | abomsa
# Processing Record 22 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 12 | zeya
# Processing Record 24 of Set 12 | kenai
# Processing Record 25 of Set 12 | goma
# Processing Record 26 of Set 12 | rosaryville
# Processing Record 27 of Set 12 | zhangye
# Processing Record 28 of Set 12 | chapais
# Processing Record 29 of Set 12 | datong
# Processing Record 30 of Set 12 | nantucket
# Processing Record 31 of Set 12 | nanae
# Processing Record 32 of Set 12 | bajil
# Processing Record 33 of Set 12 | tabuk
# Processing Record 34 of Set 12 | nicoya
# Processing Record 35 of Set 12 | jiexiu
# Processing Record 36 of Set 12 | kosice
# Processing Record 37 of Set 12 | oranjemund
# Processing Record 38 of Set 12 | kindu
# Processing Record 39 of Set 12 | asayita
# City not found. Skipping...
# Processing Record 40 of Set 12 | buala
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Kavaratti      IN  10.5669   72.6420     81.34        67           5
# 1  Provideniya      RU  64.3833 -173.3000     -8.93        90           5
# 2       Baykit      RU  61.6700   96.3700      1.11        94          59
# 3        Jutai      BR  -5.1833  -68.9000     72.84        98          68
# 4        Vaini      TO -21.2000 -175.2000     86.16        79          40
# 5          Leh      IN  34.1667   77.5833      8.82        71         100
# 6       Bethel      US  41.3712  -73.4140     42.94        68          40
# 7     Tasiilaq      GL  65.6145  -37.6368      6.96        66         100
# 8      Batagay      RU  67.6333  134.6333    -17.77        93          81
# 9    Busselton      AU -33.6500  115.3333     83.08        36           0
#
#    Wind Speed Current Description
# 0        6.31           clear sky
# 1        4.81           clear sky
# 2        2.55       broken clouds
# 3        0.78       broken clouds
# 4       11.50    scattered clouds
# 5        2.48     overcast clouds
# 6        4.61    scattered clouds
# 7        5.01     overcast clouds
# 8        2.68       broken clouds
# 9        2.98           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label = "City_ID")
